# %% [markdown]
# # **Librerias**

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns

# %% [markdown]
# ## **Carga de datos**

# %%
# Hoja 1, Esperanza de vida

Data_Esperanza = pd.read_excel('https://github.com/MoisesAlmz/Proyecto-Samsung/raw/master/Esperanza%20de%20vida%20RD.xlsx')
Data_Esperanza
# Out:
#     Fecha  Esperanza de vida - Mujeres  Esperanza de vida - Hombres  \
# 0    2021                        76.29                        69.30
# 1    2020                        76.91                        69.36
# 2    2019                        76.97                        70.47
# 3    2018                        76.50                        70.23
# 4    2017                        76.32                        70.07
# ..    ...                          ...                          ...
# 57   1964                        54.92                        50.38
# 58   1963                        54.13                        49.68
# 59   1962                        53.79                        49.26
# 60   1961                        53.20                        48.71
# 61   1960                        52.61                        48.15
#
#     Esperanza de vida
# 0               72.62
# 1               72.89
# 2               73.58
# 3               73.23
# 4               73.06
# ...

# %%
# Hoja 2, Tasa de Mortalidad

Data_Mortalidad = pd.read_excel('https://github.com/MoisesAlmz/Proyecto-Samsung/raw/master/Tasa%20de%20mortalidad.xlsx')
Data_Mortalidad
# Out:
#     Fecha  Muertes  Tasa mortalidad
# 0    2021    74245           0.0668
# 1    2020    71058           0.0646
# 2    2019    62210           0.0601
# 3    2018    62212           0.0606
# 4    2017    61339           0.0603
# ..    ...      ...              ...
# 57   1964    54998           0.1466
# 58   1963    55704           0.1532
# 59   1962    55515           0.1577
# 60   1961    55659           0.1633
# 61   1960    55717           0.1689
#
# [62 rows x 3 columns]

# %%
# Hoja 3, Suicidios

Data_Suicidios = pd.read_excel('https://github.com/MoisesAlmz/Proyecto-Samsung/raw/master/Suicidios.xlsx')
Data_Suicidios
# Out:
#     Fecha  Suicidios mujeres  Suicidios hombres  Suicidios  \
# 0    2015                134                586        720
# 1    2014                127                569        696
# 2    2013                127                560        686
# 3    2012                155                740        895
# 4    2011                114                489        603
# 5    2010                110                545        655
# 6    2009                 99                478        577
# 7    2008                 96                484        579
# 8    2007                 99                464        563
# 9    2006                 98                524        622
# 10   2005                121                679        800
# 11   2004                128                634        762
# 12   2003                111                618        729
# 13   2002                110                560        670
# 14   2001                113                607        720
# ...

# %%
# Hoja 4, Riesgo de Pobreza

Data_Pobreza = pd.read_excel('https://github.com/MoisesAlmz/Proyecto-Samsung/raw/master/Riesgo%20de%20pobreza.xlsx')
Data_Pobreza
# Out:
#     Fecha  % Riesgo Pobreza
# 0    2021             0.239
# 1    2020             0.234
# 2    2019             0.210
# 3    2018             0.228
# 4    2017             0.256
# 5    2016             0.305
# 6    2015             0.323
# 7    2014             0.363
# 8    2013             0.412
# 9    2012             0.410
# 10   2011             0.404
# 11   2010             0.416
# 12   2009             0.421
# 13   2008             0.442
# 14   2007             0.436
# 15   2006             0.442
# 16   2005             0.478
# 17   2004             0.497
# 18   2003             0.415
# 19   2002             0.328
# 20   2001             0.328
# 21   2000             0.321

# %%
# Hoja 5, Poblacion

Data_Poblacion = pd.read_excel('https://github.com/MoisesAlmz/Proyecto-Samsung/raw/master/Poblacion.xlsx')
Data_Poblacion
# Out:
#     Fecha  Densidad  Hombres  Mujeres  Población
# 0    2021       228  5582224  5535650   11117873
# 1    2020       226  5527482  5472181   10999664
# 2    2019       213  5472410  5409472   10358000
# 3    2018       211  5416994  5348537   10266000
# 4    2017       209  5360426  5286818   10169000
# ..    ...       ...      ...      ...        ...
# 57   1964        77  1880396  1871918    3752313
# 58   1963        75  1822875  1812924    3635798
# 59   1962        72  1766296  1754868    3521164
# 60   1961        70  1710688  1697727    3408415
# 61   1960        68  1656257  1641764    3298021
#
# [62 rows x 5 columns]

# %%
# Hoja 6, Natalidad

Data_Natalidad = pd.read_excel('https://github.com/MoisesAlmz/Proyecto-Samsung/raw/master/Natalidad.xlsx')
Data_Natalidad
# Out:
#     Fecha  Tasa Natalidad  Índice de Fecund.
# 0    2021          0.1843               2.27
# 1    2020          0.1878               2.30
# 2    2019          0.1929               2.34
# 3    2018          0.1976               2.38
# 4    2017          0.1999               2.39
# ..    ...             ...                ...
# 57   1964          0.4847               7.19
# 58   1963          0.4947               7.30
# 59   1962          0.5046               7.40
# 60   1961          0.5139               7.49
# 61   1960          0.5223               7.56
#
# [62 rows x 3 columns]

# %%
# Hoja 7, Indice Global de Envejecimiento (IGE)

Data_IGE = pd.read_excel('https://github.com/MoisesAlmz/Proyecto-Samsung/raw/master/Indice%20global%20de%20envejecimiento.xlsx')
Data_IGE
# Out:
#    Fecha Ranking  Índice de envejecimiento  Entorno  Competencias  Salud  \
# 0   2015     62º                     43.74    67.28         29.95  60.98
# 1   2014     62º                     44.40    67.30         26.80  61.00
# 2   2013     68º                     39.30    64.20         31.30  52.30
#
#    Ingresos
# 0     30.08
# 1     29.90
# 2     22.30

# %%
#Hoja 8, IDH

Data_IDH = pd.read_excel('https://github.com/MoisesAlmz/Proyecto-Samsung/raw/master/IDH.xlsx')
Data_IDH
# Out:
#     Fecha    IDH Ranking IDH
# 0    2021  0.767         80º
# 1    2020  0.764         82º
# 2    2019  0.771         85º
# 3    2018  0.764         86º
# 4    2017  0.757         88º
# 5    2016  0.755         88º
# 6    2015  0.736         95º
# 7    2014  0.728         98º
# 8    2013  0.722         99º
# 9    2012  0.718        100º
# 10   2011  0.713         99º
# 11   2010  0.708        102º
# 12   2009  0.701        100º
# 13   2008  0.697        102º
# 14   2007  0.692        102º
# 15   2006  0.683        102º
# 16   2005  0.674        101º
# 17   2004  0.663         99º
# 18   2003  0.659         98º
# 19   2002  0.657         97º
# 20   2001  0.651         96º
# 21   2000  0.646         95º
# 22   1999  0.640         86º
# 23   1998  0.633         87º
# 24   1997  0.627         86º
# 25   1996  0.620         87º
# 26   1995  0.613         88º
# 27   1994  0.607         86º
# 28   1993  0.600         88º
# 29   1992  0.593         88º
# 30   1991  0.583         91º
# ...

# %%
#Hoja 9, Homicidios

Data_Homicidios = pd.read_excel('https://github.com/MoisesAlmz/Proyecto-Samsung/raw/master/Homicidios%20intencionados.xlsx')
Data_Homicidios
# Out:
#     Fecha  Número de Homicidios  Homicidios Mujeres  Homicidios Hombres  \
# 0    2022                  1389                 153                1236
# 1    2021                  1172                 142                 103
# 2    2020                   961                 128                 833
# 3    2019                  1026                 145                 881
# 4    2018                  1068                 152                 916
# 5    2017                  1216                 191                1025
# 6    2016                  1616                 170                1446
# 7    2014                  1810                 187                1623
# 8    2013                  1978                   0                   0
# 9    2012                  2268                 201                2067
# 10   2011                  2513                 233                 228
# 11   2010                  2474                 210                2264
# ...

# %% [markdown]
# ## **Grafico de datos**

# %%
# Graficar
plt.figure(figsize=(10, 6))  # Tamaño de la figura
plt.plot(Data_Esperanza["Fecha"], Data_Esperanza["Esperanza de vida - Mujeres"], label="Esperanza de vida - Mujeres")
plt.plot(Data_Esperanza["Fecha"], Data_Esperanza["Esperanza de vida - Hombres"], label="Esperanza de vida - Hombres")
plt.plot(Data_Esperanza["Fecha"], Data_Esperanza["Esperanza de vida"], label="Esperanza de vida")

# Configurar título y etiquetas de los ejes
plt.title('Esperanza de Vida')
plt.xlabel('Fecha')
plt.ylabel('Esperanza de Vida')
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mayor claridad
plt.grid(True)  # Activar cuadrícula

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Graficar
plt.figure(figsize=(15, 15))  # Tamaño de la figura
#plt.plot(Data_Mortalidad["Fecha"], Data_Mortalidad["Muertes"], label="Muertes")
plt.plot(Data_Mortalidad["Fecha"], Data_Mortalidad["Tasa mortalidad"], label="Tasa mortalidad")

# Configurar título y etiquetas de los ejes
plt.title('Porcentaje de mortalidad')
plt.xlabel('Fecha')
plt.ylabel('Porcentaje de mortalidad')
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mayor claridad
plt.grid(True)  # Activar cuadrícula

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Graficar
plt.figure(figsize=(10, 10))  # Tamaño de la figura
plt.plot(Data_Mortalidad["Fecha"], Data_Mortalidad["Muertes"], label="Muertes")

# Configurar título y etiquetas de los ejes
plt.title('Muertes')
plt.xlabel('Fecha')
plt.ylabel('Muertes')
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mayor claridad
plt.grid(True)  # Activar cuadrícula

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Graficar
plt.figure(figsize=(14, 12))  # Tamaño de la figura
plt.plot(Data_Suicidios["Fecha"], Data_Suicidios["Suicidios mujeres"], label="Suicidios mujeres")
plt.plot(Data_Suicidios["Fecha"], Data_Suicidios["Suicidios hombres"], label="Suicidios hombres")
plt.plot(Data_Suicidios["Fecha"], Data_Suicidios["Suicidios"], label="Suicidios")
plt.plot(Data_Suicidios["Fecha"], Data_Suicidios["Suicidios tasa femenina"], label="Suicidios tasa femenina")
plt.plot(Data_Suicidios["Fecha"], Data_Suicidios["Suicidios tasa masculina"], label="Suicidios tasa masculina")
plt.plot(Data_Suicidios["Fecha"], Data_Suicidios["Suicidios por 100.000"], label="Suicidios por 100.000")



# Configurar título y etiquetas de los ejes
plt.title('Suicidios')
plt.xlabel('Fecha')
plt.ylabel('Suicidios')
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mayor claridad
plt.grid(True)  # Activar cuadrícula

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Graficar
plt.figure(figsize=(10, 6))  # Tamaño de la figura
plt.plot(Data_Pobreza["Fecha"], Data_Pobreza["% Riesgo Pobreza"], label="% Riesgo Pobreza")



# Configurar título y etiquetas de los ejes
plt.title('% Riesgo Pobreza')
plt.xlabel('Fecha')
plt.ylabel('% Riesgo Pobreza')
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mayor claridad
plt.grid(True)  # Activar cuadrícula

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Graficar
plt.figure(figsize=(10, 10))  # Tamaño de la figura
#plt.plot(Data_Poblacion["Fecha"], Data_Poblacion["Densidad"], label="Densidad")
plt.plot(Data_Poblacion["Fecha"], Data_Poblacion["Hombres"], label="Hombres")
plt.plot(Data_Poblacion["Fecha"], Data_Poblacion["Mujeres"], label="Mujeres")
plt.plot(Data_Poblacion["Fecha"], Data_Poblacion["Población"], label="Población")

# Configurar título y etiquetas de los ejes
plt.title('Población')
plt.xlabel('Fecha')
plt.ylabel('Población')
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mayor claridad
plt.grid(True)  # Activar cuadrícula

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Graficar
plt.figure(figsize=(14, 12))  # Tamaño de la figura
plt.plot(Data_Natalidad["Fecha"], Data_Natalidad["Tasa Natalidad"], label="Tasa Natalidad")
plt.plot(Data_Natalidad["Fecha"], Data_Natalidad["Índice de Fecund."], label="Índice de Fecund.")

# Configurar título y etiquetas de los ejes
plt.title('Tasa Natalidad')
plt.xlabel('Fecha')
plt.ylabel('Tasa Natalidad')
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mayor claridad
plt.grid(True)  # Activar cuadrícula

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Graficar
plt.figure(figsize=(10, 10))  # Tamaño de la figura
plt.plot(Data_IGE["Fecha"], Data_IGE["Ranking"], label="Ranking")
plt.plot(Data_IGE["Fecha"], Data_IGE["Índice de envejecimiento"], label="Índice de envejecimiento")
plt.plot(Data_IGE["Fecha"], Data_IGE["Entorno"], label="Entorno")
plt.plot(Data_IGE["Fecha"], Data_IGE["Competencias"], label="Competencias")
plt.plot(Data_IGE["Fecha"], Data_IGE["Salud"], label="Salud")
plt.plot(Data_IGE["Fecha"], Data_IGE["Ingresos"], label="Ingresos")

# Configurar título y etiquetas de los ejes
plt.title('IGE')
plt.xlabel('Fecha')
plt.ylabel('IGE')
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mayor claridad
plt.grid(True)  # Activar cuadrícula

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Graficar
plt.figure(figsize=(25, 12))  # Tamaño de la figura
plt.plot(Data_IDH["Fecha"], Data_IDH["IDH"], label="IDH")
plt.plot(Data_IDH["Fecha"], Data_IDH["Ranking IDH"], label="Ranking IDH")

# Configurar título y etiquetas de los ejes
plt.title('IDH')
plt.xlabel('Fecha')
plt.ylabel('IDH')
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mayor claridad
plt.grid(True)  # Activar cuadrícula

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Graficar
plt.figure(figsize=(12, 12))  # Tamaño de la figura
plt.plot(Data_Homicidios["Fecha"], Data_Homicidios["Número de Homicidios"], label="Número de Homicidios")
plt.plot(Data_Homicidios["Fecha"], Data_Homicidios["Homicidios Mujeres"], label="Homicidios Mujeres")
plt.plot(Data_Homicidios["Fecha"], Data_Homicidios["Homicidios Hombres"], label="Homicidios Hombres")
plt.plot(Data_Homicidios["Fecha"], Data_Homicidios["Homicidios Mujeres por familiares"], label="Homicidios Mujeres por familiares")
plt.plot(Data_Homicidios["Fecha"], Data_Homicidios["Homicidios hombres por familiares"], label="Homicidios hombres por familiares")
plt.plot(Data_Homicidios["Fecha"], Data_Homicidios["Homicidios por 100.000"], label="Homicidios por 100.000")

# Configurar título y etiquetas de los ejes
plt.title('Homicidios')
plt.xlabel('Fecha')
plt.ylabel('Homicidios')
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mayor claridad
plt.grid(True)  # Activar cuadrícula

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

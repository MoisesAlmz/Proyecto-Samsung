# %% [markdown]
# # **Librerias**

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns

# %% [markdown]
# ## **Carga de datos**

# %%
#Hoja 1, esperanza de vida

read_data_excel = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Esperanza de vida RD.xlsx")
read_data_excel
# Out:
#     Fecha Esperanza de vida - Mujeres Esperanza de vida - Hombres  \
# 0    2021                       76,29                       69,30
# 1    2020                       76,91                       69,36
# 2    2019                       76,97                       70,47
# 3    2018                       76,50                       70,23
# 4    2017                       76,32                       70,07
# ..    ...                         ...                         ...
# 57   1964                       54,92                       50,38
# 58   1963                       54,13                       49,68
# 59   1962                       53,79                       49,26
# 60   1961                       53,20                       48,71
# 61   1960                       52,61                       48,15
#
#    Esperanza de vida
# 0              72,62
# 1              72,89
# 2              73,58
# 3              73,23
# 4              73,06
# ..               ...
# ...

# %%
read_data_excel.plot()


plt.show()

# %%
#Hoja 2, mortalidad

read_data_excel2 = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Tasa de mortalidad.xlsx")
read_data_excel2
# Out:
#     Fecha  Muertes Tasa mortalidad
# 0    2021   74.245           6,68‰
# 1    2020   71.058           6,46‰
# 2    2019   62.210           6,01‰
# 3    2018   62.212           6,06‰
# 4    2017   61.339           6,03‰
# ..    ...      ...             ...
# 57   1964   54.998          14,66‰
# 58   1963   55.704          15,32‰
# 59   1962   55.515          15,77‰
# 60   1961   55.659          16,33‰
# 61   1960   55.717          16,89‰
#
# [62 rows x 3 columns]

# %%
#Hoja 2, mortalidad

read_data_excel3 = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Tasa de mortalidad.xlsx")
read_data_excel3
# Out:
#     Fecha  Muertes Tasa mortalidad
# 0    2021   74.245           6,68‰
# 1    2020   71.058           6,46‰
# 2    2019   62.210           6,01‰
# 3    2018   62.212           6,06‰
# 4    2017   61.339           6,03‰
# ..    ...      ...             ...
# 57   1964   54.998          14,66‰
# 58   1963   55.704          15,32‰
# 59   1962   55.515          15,77‰
# 60   1961   55.659          16,33‰
# 61   1960   55.717          16,89‰
#
# [62 rows x 3 columns]

# %%
#Hoja 3, Suicidios

read_data_excel4 = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Suicidios.xlsx")
read_data_excel4
# Out:
#     Fecha  Suicidios mujeres  Suicidios hombres  Suicidios  \
# 0    2015                134                586        720
# 1    2014                127                569        696
# 2    2013                127                560        686
# 3    2012                155                740        895
# 4    2011                114                489        603
# 5    2010                110                545        655
# 6    2009                 99                478        577
# 7    2008                 96                484        579
# 8    2007                 99                464        563
# 9    2006                 98                524        622
# 10   2005                121                679        800
# 11   2004                128                634        762
# 12   2003                111                618        729
# 13   2002                110                560        670
# 14   2001                113                607        720
# ...

# %%
#Hoja 4, Riesgo de pobreza

read_data_excel5 = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Riesgo de pobreza.xlsx")
read_data_excel5
# Out:
#     Fecha % Riesgo Pobreza
# 0    2021            23,9%
# 1    2020            23,4%
# 2    2019            21,0%
# 3    2018            22,8%
# 4    2017            25,6%
# 5    2016            30,5%
# 6    2015            32,3%
# 7    2014            36,3%
# 8    2013            41,2%
# 9    2012            41,0%
# 10   2011            40,4%
# 11   2010            41,6%
# 12   2009            42,1%
# 13   2008            44,2%
# 14   2007            43,6%
# 15   2006            44,2%
# 16   2005            47,8%
# 17   2004            49,7%
# 18   2003            41,5%
# 19   2002            32,8%
# 20   2001            32,8%
# 21   2000            32,1%

# %%
#Hoja 5, Poblacion

read_data_excel6 = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Poblacion.xlsx")
read_data_excel6
# Out:
#     Fecha  Densidad    Hombres    Mujeres   Población
# 0    2021       228  5.582.224  5.535.650  11.117.873
# 1    2020       226  5.527.482  5.472.181  10.999.664
# 2    2019       213  5.472.410  5.409.472  10.358.000
# 3    2018       211  5.416.994  5.348.537  10.266.000
# 4    2017       209  5.360.426  5.286.818  10.169.000
# ..    ...       ...        ...        ...         ...
# 57   1964        77  1.880.396  1.871.918   3.752.313
# 58   1963        75  1.822.875  1.812.924   3.635.798
# 59   1962        72  1.766.296  1.754.868   3.521.164
# 60   1961        70  1.710.688  1.697.727   3.408.415
# 61   1960        68  1.656.257  1.641.764   3.298.021
#
# [62 rows x 5 columns]

# %%
#Hoja 6, Natalidad

read_data_excel7 = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Natalidad.xlsx")
read_data_excel7
# Out:
#     Fecha Tasa Natalidad Índice de Fecund.
# 0    2021         18,43‰              2,27
# 1    2020         18,78‰              2,30
# 2    2019         19,29‰              2,34
# 3    2018         19,76‰              2,38
# 4    2017         19,99‰              2,39
# ..    ...            ...               ...
# 57   1964         48,47‰              7,19
# 58   1963         49,47‰              7,30
# 59   1962         50,46‰              7,40
# 60   1961         51,39‰              7,49
# 61   1960         52,23‰              7,56
#
# [62 rows x 3 columns]

# %%
#Hoja 7, IGE

read_data_excel8 = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Indice global de envejecimiento.xlsx")
read_data_excel8
# Out:
#    Fecha Ranking Índice de envejecimiento Entorno Competencias  Salud Ingresos
# 0   2015     62º                    43,74   67,28        29,95  60,98    30,08
# 1   2014     62º                    44,40   67,30        26,80  61,00    29,90
# 2   2013     68º                    39,30   64,20        31,30  52,30    22,30

# %%
#Hoja 8, IDH

read_data_excel9 = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\IDH.xlsx")
read_data_excel9
# Out:
#     Fecha    IDH Ranking IDH
# 0    2021  0,767         80º
# 1    2020  0,764         82º
# 2    2019  0,771         85º
# 3    2018  0,764         86º
# 4    2017  0,757         88º
# 5    2016  0,755         88º
# 6    2015  0,736         95º
# 7    2014  0,728         98º
# 8    2013  0,722         99º
# 9    2012  0,718        100º
# 10   2011  0,713         99º
# 11   2010  0,708        102º
# 12   2009  0,701        100º
# 13   2008  0,697        102º
# 14   2007  0,692        102º
# 15   2006  0,683        102º
# 16   2005  0,674        101º
# 17   2004  0,663         99º
# 18   2003  0,659         98º
# 19   2002  0,657         97º
# 20   2001  0,651         96º
# 21   2000  0,646         95º
# 22   1999  0,640         86º
# 23   1998  0,633         87º
# 24   1997  0,627         86º
# 25   1996  0,620         87º
# 26   1995  0,613         88º
# 27   1994  0,607         86º
# 28   1993  0,600         88º
# 29   1992  0,593         88º
# 30   1991  0,583         91º
# ...

# %%
#Hoja 9, Homicidios

read_data_excel10 = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Homicidios intencionados.xlsx")
read_data_excel10
# Out:
#     Fecha  Número de Homicidios  Homicidios Mujeres  Homicidios Hombres  \
# 0    2022                 1.389               153.0               1.236
# 1    2021                 1.172               142.0               1.030
# 2    2020               961.000               128.0             833.000
# 3    2019                 1.026               145.0             881.000
# 4    2018                 1.068               152.0             916.000
# 5    2017                 1.216               191.0               1.025
# 6    2016                 1.616               170.0               1.446
# 7    2014                 1.810               187.0               1.623
# 8    2013                 1.978                 NaN                 NaN
# 9    2012                 2.268               201.0               2.067
# 10   2011                 2.513               233.0               2.280
# 11   2010                 2.474               210.0               2.264
# ...

# %% [markdown]
# ## **Grafico de datos**

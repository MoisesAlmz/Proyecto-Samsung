# %% [markdown]
# # **Librerias**

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns

# %% [markdown]
# ## **Carga de datos**

# %%
#Hoja 1, esperanza de vida

Data_Esperanza = pd.read_excel(r"C:\Users\kevin\Desktop\Clases y Tareas Saul\3-Curso Python\Proyecto-Samsung-master\Esperanza de vida RD.xlsx")
Data_Esperanza
# Out:
#     Fecha  Esperanza de vida - Mujeres  Esperanza de vida - Hombres  \
# 0    2021                        76.29                        69.30
# 1    2020                        76.91                        69.36
# 2    2019                        76.97                        70.47
# 3    2018                        76.50                        70.23
# 4    2017                        76.32                        70.07
# ..    ...                          ...                          ...
# 57   1964                        54.92                        50.38
# 58   1963                        54.13                        49.68
# 59   1962                        53.79                        49.26
# 60   1961                        53.20                        48.71
# 61   1960                        52.61                        48.15
#
#     Esperanza de vida
# 0               72.62
# 1               72.89
# 2               73.58
# 3               73.23
# 4               73.06
# ...

# %%
#Hoja 2, mortalidad

read_data_excel = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Tasa de mortalidad.xlsx")
read_data_excel
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[71], line 3
#       1 #Hoja 2, mortalidad
# ----> 3 read_data_excel = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Tasa de mortalidad.xlsx")
#       4 read_data_excel
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
#Hoja 2, mortalidad

read_data_excel = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Tasa de mortalidad.xlsx")
read_data_excel
# Out:
#     Fecha  Muertes Tasa mortalidad
# 0    2021   74.245           6,68‰
# 1    2020   71.058           6,46‰
# 2    2019   62.210           6,01‰
# 3    2018   62.212           6,06‰
# 4    2017   61.339           6,03‰
# ..    ...      ...             ...
# 57   1964   54.998          14,66‰
# 58   1963   55.704          15,32‰
# 59   1962   55.515          15,77‰
# 60   1961   55.659          16,33‰
# 61   1960   55.717          16,89‰
#
# [62 rows x 3 columns]

# %%
#Hoja 3, Suicidios

read_data_excel = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Suicidios.xlsx")
read_data_excel
# Out:
#     Fecha  Suicidios mujeres  Suicidios hombres  Suicidios  \
# 0    2015                134                586        720
# 1    2014                127                569        696
# 2    2013                127                560        686
# 3    2012                155                740        895
# 4    2011                114                489        603
# 5    2010                110                545        655
# 6    2009                 99                478        577
# 7    2008                 96                484        579
# 8    2007                 99                464        563
# 9    2006                 98                524        622
# 10   2005                121                679        800
# 11   2004                128                634        762
# 12   2003                111                618        729
# 13   2002                110                560        670
# 14   2001                113                607        720
# ...

# %%
#Hoja 4, Riesgo de pobreza

read_data_excel = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Riesgo de pobreza.xlsx")
read_data_excel
# Out:
#     Fecha % Riesgo Pobreza
# 0    2021            23,9%
# 1    2020            23,4%
# 2    2019            21,0%
# 3    2018            22,8%
# 4    2017            25,6%
# 5    2016            30,5%
# 6    2015            32,3%
# 7    2014            36,3%
# 8    2013            41,2%
# 9    2012            41,0%
# 10   2011            40,4%
# 11   2010            41,6%
# 12   2009            42,1%
# 13   2008            44,2%
# 14   2007            43,6%
# 15   2006            44,2%
# 16   2005            47,8%
# 17   2004            49,7%
# 18   2003            41,5%
# 19   2002            32,8%
# 20   2001            32,8%
# 21   2000            32,1%

# %%
#Hoja 5, Poblacion

read_data_excel = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Poblacion.xlsx")
read_data_excel
# Out:
#     Fecha  Densidad    Hombres    Mujeres   Población
# 0    2021       228  5.582.224  5.535.650  11.117.873
# 1    2020       226  5.527.482  5.472.181  10.999.664
# 2    2019       213  5.472.410  5.409.472  10.358.000
# 3    2018       211  5.416.994  5.348.537  10.266.000
# 4    2017       209  5.360.426  5.286.818  10.169.000
# ..    ...       ...        ...        ...         ...
# 57   1964        77  1.880.396  1.871.918   3.752.313
# 58   1963        75  1.822.875  1.812.924   3.635.798
# 59   1962        72  1.766.296  1.754.868   3.521.164
# 60   1961        70  1.710.688  1.697.727   3.408.415
# 61   1960        68  1.656.257  1.641.764   3.298.021
#
# [62 rows x 5 columns]

# %%
#Hoja 6, Natalidad

read_data_excel = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Natalidad.xlsx")
read_data_excel
# Out:
#     Fecha Tasa Natalidad Índice de Fecund.
# 0    2021         18,43‰              2,27
# 1    2020         18,78‰              2,30
# 2    2019         19,29‰              2,34
# 3    2018         19,76‰              2,38
# 4    2017         19,99‰              2,39
# ..    ...            ...               ...
# 57   1964         48,47‰              7,19
# 58   1963         49,47‰              7,30
# 59   1962         50,46‰              7,40
# 60   1961         51,39‰              7,49
# 61   1960         52,23‰              7,56
#
# [62 rows x 3 columns]

# %%
#Hoja 7, IGE

read_data_excel = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Indice global de envejecimiento.xlsx")
read_data_excel
# Out:
#    Fecha Ranking Índice de envejecimiento Entorno Competencias  Salud Ingresos
# 0   2015     62º                    43,74   67,28        29,95  60,98    30,08
# 1   2014     62º                    44,40   67,30        26,80  61,00    29,90
# 2   2013     68º                    39,30   64,20        31,30  52,30    22,30

# %%
#Hoja 8, IDH

read_data_excel = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\IDH.xlsx")
read_data_excel
# Out:
#     Fecha    IDH Ranking IDH
# 0    2021  0,767         80º
# 1    2020  0,764         82º
# 2    2019  0,771         85º
# 3    2018  0,764         86º
# 4    2017  0,757         88º
# 5    2016  0,755         88º
# 6    2015  0,736         95º
# 7    2014  0,728         98º
# 8    2013  0,722         99º
# 9    2012  0,718        100º
# 10   2011  0,713         99º
# 11   2010  0,708        102º
# 12   2009  0,701        100º
# 13   2008  0,697        102º
# 14   2007  0,692        102º
# 15   2006  0,683        102º
# 16   2005  0,674        101º
# 17   2004  0,663         99º
# 18   2003  0,659         98º
# 19   2002  0,657         97º
# 20   2001  0,651         96º
# 21   2000  0,646         95º
# 22   1999  0,640         86º
# 23   1998  0,633         87º
# 24   1997  0,627         86º
# 25   1996  0,620         87º
# 26   1995  0,613         88º
# 27   1994  0,607         86º
# 28   1993  0,600         88º
# 29   1992  0,593         88º
# 30   1991  0,583         91º
# ...

# %%
#Hoja 9, Homicidios

read_data_excel = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Homicidios intencionados.xlsx")
read_data_excel
# Out:
#     Fecha  Número de Homicidios  Homicidios Mujeres  Homicidios Hombres  \
# 0    2022                 1.389               153.0               1.236
# 1    2021                 1.172               142.0               1.030
# 2    2020               961.000               128.0             833.000
# 3    2019                 1.026               145.0             881.000
# 4    2018                 1.068               152.0             916.000
# 5    2017                 1.216               191.0               1.025
# 6    2016                 1.616               170.0               1.446
# 7    2014                 1.810               187.0               1.623
# 8    2013                 1.978                 NaN                 NaN
# 9    2012                 2.268               201.0               2.067
# 10   2011                 2.513               233.0               2.280
# 11   2010                 2.474               210.0               2.264
# ...

# %% [markdown]
# ## **Grafico de datos**

# %%
# Graficar
plt.figure(figsize=(10, 6))  # Tamaño de la figura
plt.plot(Data_Esperanza["Fecha"], Data_Esperanza["Esperanza de vida - Mujeres"], label="Esperanza de vida - Mujeres")
plt.plot(Data_Esperanza["Fecha"], Data_Esperanza["Esperanza de vida - Hombres"], label="Esperanza de vida - Hombres")
plt.plot(Data_Esperanza["Fecha"], Data_Esperanza["Esperanza de vida"], label="Esperanza de vida")

# Configurar título y etiquetas de los ejes
plt.title('Esperanza de Vida')
plt.xlabel('Fecha')
plt.ylabel('Esperanza de Vida')
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mayor claridad
plt.grid(True)  # Activar cuadrícula

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear un DataFrame con los datos
data = {
    'Fecha': ['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991', '1990', '1989', '1988', '1987', '1986', '1985', '1984', '1983', '1982', '1981', '1980', '1979', '1978', '1977', '1976', '1975', '1974', '1973', '1972', '1971', '1970', '1969', '1968', '1967', '1966', '1965', '1964', '1963', '1962', '1961', '1960'],
    'Esperanza de vida - Mujeres': [76.29, 76.91, 76.97, 76.5, 76.32, 76.3, 76.38, 76.4, 76.32, 76.17, 75.86, 75.66, 75.28, 74.83, 74.28, 73.86, 73.41, 72.81, 72.78, 72.69, 72.52, 72.38, 72.25, 71.98, 72.0, 71.85, 71.69, 71.48, 71.19, 70.85, 70.43, 69.9, 69.27, 68.54, 67.78, 67.03, 66.33, 65.75, 65.27, 64.86, 64.48, 64.12, 63.02, 63.26, 62.76, 62.22, 61.64, 61.04, 60.42, 59.8, 59.16, 58.52, 57.89, 57.27, 56.67, 56.04, 55.27, 54.92, 54.13, 53.79, 53.2, 52.61],
    'Esperanza de vida - Hombres': [69.3, 69.36, 70.47, 70.23, 70.07, 69.95, 69.83, 69.66, 69.46, 69.24, 68.98, 68.93, 68.84, 68.81, 68.73, 68.71, 68.56, 68.06, 67.96, 67.4, 67.02, 66.71, 66.54, 66.41, 66.49, 66.48, 66.39, 66.18, 65.82, 65.39, 64.9, 64.4, 63.91, 63.45, 62.98, 62.51, 62.03, 61.54, 61.04, 60.53, 60.01, 59.51, 58.6, 58.53, 58.04, 57.53, 56.99, 56.43, 55.83, 55.21, 54.58, 53.94, 53.32, 52.7, 52.1, 51.49, 47.05, 50.38, 49.68, 49.26, 48.71, 48.15],
    'Esperanza de vida': [72.62, 72.89, 73.58, 73.23, 73.06, 72.99, 72.95, 72.87, 72.71, 72.51, 72.22, 72.09, 71.87, 71.66, 71.37, 71.17, 70.88, 70.33, 70.27, 69.92, 69.64, 69.42, 69.28, 69.1, 69.17, 69.1, 68.9, 68.7, 68.47, 68.08, 67.63, 67.11, 66.55, 65.95, 65.34, 64.73, 64.14, 63.6, 63.11, 62.65, 62.19, 61.75, 60.75, 60.82, 60.32, 59.79, 59.24, 58.65, 58.60, 57.42, 56.78, 56.15, 55.51, 54.89, 54.29, 53.67, 50.86, 52.54, 51.8, 51.41, 50.84, 50.26]
}

# Crear un DataFrame
df = pd.DataFrame(data)

# Configurar el tamaño de la figura
plt.figure(figsize=(10, 6))

# Graficar las líneas
plt.plot(df['Fecha'], df['Esperanza de vida - Mujeres'], label='Esperanza de vida - Mujeres')
plt.plot(df['Fecha'], df['Esperanza de vida - Hombres'], label='Esperanza de vida - Hombres')
plt.plot(df['Fecha'], df['Esperanza de vida'], label='Esperanza de vida')

# Configurar título y etiquetas de los ejes
plt.title('Esperanza de Vida')
plt.xlabel('Fecha')
plt.ylabel('Esperanza de Vida')
plt.xticks(rotation=45)  # Rotar etiquetas del eje x para mayor claridad
plt.grid(True)  # Activar cuadrícula

# Mostrar la leyenda
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

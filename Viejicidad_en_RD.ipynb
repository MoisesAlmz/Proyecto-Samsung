# %% [markdown]
# # **Librerias**

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns

# %% [markdown]
# ## **Carga de datos**

# %%
read_data_excel = pd.read_excel(r"C:\Users\Moises Almanzar\Desktop\Proyecto Samsung\Esperanza de vida RD.xlsx")

read_data_excel
# Out:
#    República Dominicana - Esperanza de vida al nacer  \
# 0                                              Fecha
# 1                                               2021
# 2                                               2020
# 3                                               2019
# 4                                               2018
# ..                                               ...
# 58                                              1964
# 59                                              1963
# 60                                              1962
# 61                                              1961
# 62                                              1960
#
#                      Unnamed: 1                   Unnamed: 2  \
# 0   Esperanza de vida - Mujeres  Esperanza de vida - Hombres
# 1                         76,29                        69,30
# 2                         76,91                        69,36
# 3                         76,97                        70,47
# ...
